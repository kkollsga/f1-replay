# %% [markdown]
# # F1 Race Viewer - 2024 Monaco Grand Prix
#
# Launch the interactive race viewer for the 2024 Monaco Grand Prix (Round 8)

# %%
from f1_race import Manager

# Create manager
manager = Manager()
#manager.process_season(2024, force_update=True)
#manager.process_season(2025, force_update=True)
# Launch 2024 Monaco Grand Prix (Round 8) race viewer
# The viewer will start on http://localhost:5002
manager.race(2024, 21, port=5002, debug=False, force_update=False)
# Out:
# ✓ FastF1 cache: race_data/.fastf1_cache
# ✓ DataLoader initialized: race_data
#
# 🏎️  Loading race: 2024 Round 21...
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# ✓ Loaded weekend from cache: São Paulo Grand Prix
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# ✓ Loaded weekend from cache: São Paulo Grand Prix
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# ✓ Loaded session from cache: R
# ✓ Loaded: São Paulo Grand Prix (2024)
#
# 🚀 Starting Flask app on http://0.0.0.0:5002...
#  * Serving Flask app 'f1_race.api.app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5002
#  * Running on http://10.5.0.2:5002
# Press CTRL+C to quit
# 127.0.0.1 - - [29/Dec/2025 01:04:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:04:30] "GET /api/seasons HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:04:30] "GET /api/weekend/2024/21 HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:04:30] "GET /apple-touch-icon-precomposed.png HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Dec/2025 01:04:30] "GET /apple-touch-icon.png HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Dec/2025 01:04:30] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [29/Dec/2025 01:04:30] "GET /favicon.ico HTTP/1.1" 404 -
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# ✓ Loaded weekend from cache: São Paulo Grand Prix
# 127.0.0.1 - - [29/Dec/2025 01:04:31] "GET /api/session/2024/21/R?telemetry_fields=session_time,LapNumber,X,Y,Distance,progress,TimeToDriverAhead,status HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:05:02] "GET /api/weekend/2024/24 HTTP/1.1" 200 -
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
#
# ✓ Loaded weekend from cache: Abu Dhabi Grand Prix
# ✓ Loaded weekend from cache: Abu Dhabi Grand Prix
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# ✓ Loaded weekend from cache: Abu Dhabi Grand Prix
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# ✓ Loaded session from cache: R
# 127.0.0.1 - - [29/Dec/2025 01:05:04] "GET /api/session/2024/24/R HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:05:04] "GET /?year=2024&round=24 HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:05:04] "GET /api/weekend/2024/24 HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:05:04] "GET /api/seasons HTTP/1.1" 200 -
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# 127.0.0.1 - - [29/Dec/2025 01:05:05] "GET /api/session/2024/24/R?telemetry_fields=session_time,LapNumber,X,Y,Distance,progress,TimeToDriverAhead,status HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:06:51] "GET /api/weekend/2025/22 HTTP/1.1" 200 -
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
#
# ✓ Loaded weekend from cache: Las Vegas Grand Prix
# ✓ Loaded weekend from cache: Las Vegas Grand Prix
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# ✓ Loaded weekend from cache: Las Vegas Grand Prix
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# ✓ Loaded session from cache: R
# 127.0.0.1 - - [29/Dec/2025 01:06:52] "GET /api/session/2025/22/R HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:06:52] "GET /?year=2025&round=22 HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:06:52] "GET /api/weekend/2025/22 HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:06:52] "GET /api/seasons HTTP/1.1" 200 -
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# 127.0.0.1 - - [29/Dec/2025 01:06:53] "GET /api/session/2025/22/R?telemetry_fields=session_time,LapNumber,X,Y,Distance,progress,TimeToDriverAhead,status HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:07:19] "GET /api/weekend/2025/8 HTTP/1.1" 200 -
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# ✓ Loaded weekend from cache: Monaco Grand Prix
# ✓ Loaded weekend from cache: Monaco Grand Prix
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# ✓ Loaded weekend from cache: Monaco Grand Prix
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# ✓ Loaded session from cache: R
# 127.0.0.1 - - [29/Dec/2025 01:07:20] "GET /api/session/2025/8/R HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:07:20] "GET /?year=2025&round=8 HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:07:20] "GET /api/weekend/2025/8 HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Dec/2025 01:07:20] "GET /api/seasons HTTP/1.1" 200 -
# ✓ Loaded seasons from cache: [2020, 2021, 2022, 2023, 2024, 2025]
# 127.0.0.1 - - [29/Dec/2025 01:07:22] "GET /api/session/2025/8/R?telemetry_fields=session_time,LapNumber,X,Y,Distance,progress,TimeToDriverAhead,status HTTP/1.1" 200 -
