# %% [markdown]
# # F1 Race Viewer - 2024 Monaco Grand Prix
#
# Launch the interactive race viewer for the 2024 Monaco Grand Prix (Round 8)

# %%
from f1_replay import Manager

# Create manager
manager = Manager()
#manager.process_season(2024, force_update=True)
#manager.process_season(2025, force_update=True)
# Launch 2024 Monaco Grand Prix (Round 8) race viewer
# The viewer will start on http://localhost:5002
manager.race(2024, 21, port=5002, debug=False, force_update=True)
# Out:
# ✓ FastF1 cache: race_data/.fastf1_cache
# ✓ DataLoader initialized: race_data
#
# 🏎️  Loading race: 2024 Round 21...
# ✓ Loaded seasons from cache: [2023, 2024]
#
# 📡 Building weekend data from FastF1...
# → Loading weekend 2024 Round 21...
#   → Building circuit data...
#   ✓ Track: 542 points, 4234m
#     In-lap: 926 points
#     Out-lap: 690 points
#     Clipped: 586 points (from 1616)
#   ✓ Pit lane: 586 points, 3694m
#   ✓ Extracted rotation: 258.0°
#   ✓ Extracted marshal sectors: 16 sectors
#   ✓ Weekend complete: São Paulo Grand Prix
# ✓ Cached weekend to race_data/2024/21_São_Paulo/Weekend.pkl
#
# ✓ Loaded seasons from cache: [2023, 2024]
# ✓ Loaded weekend from cache: São Paulo Grand Prix
# ✓ Loaded seasons from cache: [2023, 2024]
#
# 📡 Building session data from FastF1...
# → Loading session 2024 R21 R...
#   → Building complete telemetry (time, progress, status, gaps, order)...
#     ✓ VER: 47414 raw points
#     ✓ GAS: 47635 raw points
#     ✓ PER: 48119 raw points
# ...
